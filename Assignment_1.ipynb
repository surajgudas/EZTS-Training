# %%
# AI ML Bootcamp
# ASSIGNMENT-1

# %%
#1.Implement the methods of strings with examples.

#strings
str="Ai ML Bootcamp"
print(str[0])
print(str[-2])

#slicing
print(str[0:7])

#from:to(n-1):3
print(str[0:5:3])

#reverse of string
print(str[::-1])

#string methods
string="i am learning python language"
print(string.upper())
print(string.lower())
print(string.swapcase())
print(string.lstrip())

#string operations
str1="python"
str2="programming"
print(str1+str2)
print(str1*2)
print(str1+str1)

#Comparing string
str1 = "i want to become developer"
str2 = "I like Python"
print(str1==str2)
# Out:
# A
# m
# Ai ML B
# AM
# pmactooB LM iA
# I AM LEARNING PYTHON LANGUAGE
# i am learning python language
# I AM LEARNING PYTHON LANGUAGE
# i am learning python language
# pythonprogramming
# pythonpython
# pythonpython
# False

# %%
#2.Implement the methods of list with examples

#lists
list1=[11,23,34,45]
list2=[12,"python","5.2"]
list3=["AI","ML","Bootcamp"]

#indexing
print(list1[2])
print(list1[-3])

#slicing
print(list1[:5])

#nested list
list4=["coding",list1,list2]
print(list4[0][0:6])
print(list4[2][1:2][0][0])

#list method
list1.append(76)
print(list1)

l1=[41,23,53,94,72,36,24,49,61,48,41]

print(l1.count(4))
print(len(l1))
print(l1[::-1])
l1.sort()
print(l1)
# Out:
# 34
# 23
# [11, 23, 34, 45]
# coding
# p
# [11, 23, 34, 45, 76]
# 0
# 11
# [41, 48, 61, 49, 24, 36, 72, 94, 53, 23, 41]
# [23, 24, 36, 41, 41, 48, 49, 53, 61, 72, 94]

# %%
#3.Implement methods of tuples with examples.

#Tuples
tup1=(11,23,34,45)
tup2=("suraj",1.1,5)
tup3=("python",tup1,tup2)
print(tup3[-1][-1])

#tuple methods
print(tup1.count(1))
print(tup1.index(23))
print(max(tup1))
print(min(tup1))
print(tup1[2:6])
print(tup1[:-5])
print(tup1[5:])
print(tup1[:])
# Out:
# 5
# 0
# 1
# 45
# 11
# (34, 45)
# ()
# ()
# (11, 23, 34, 45)

# %%
#4.Implement the methods of dictionary with examples.
#dictionaries
dict1={'name':'suraj',212:'maths'}
print(dict1['name'])
print(dict1.keys())
print(dict1.values())
print(dict1.get("name"))

Items_list = {1: "apples", 2: "eggs", 3: "Peanut Butter"}
print(Items_list)
del Items_list[1]
print(Items_list)
# Out:
# suraj
# dict_keys(['name', 212])
# dict_values(['suraj', 'maths'])
# suraj
# {1: 'apples', 2: 'eggs', 3: 'Peanut Butter'}
# {2: 'eggs', 3: 'Peanut Butter'}

# %%
#5.Implement the methods of sets with examples.
#sets
set1={33,12,33,44}
set2={3,2.4,"hello world"}

list1=[11,21,77,55]
print(list1)
set3=set(list1)
print(set3)
#set methods
set1.add(55)
print(set1)

set2.update([5,6])
print(set2)

set1.discard(11)
print(set1)

list2=list(set1)
print(list2)

#set operation
c={11,22,33,44}
d={44,55,66,77}

#union
print(c|d)
print(c.union(d))
print(d.union(c))

#intersection
print(c&d)
print(c.intersection(d))
print(d.intersection(c))

#difference
print(c-d)
print(c.difference(d))
print(d-c)
print(d.difference(c))
# Out:
# [11, 21, 77, 55]
# {11, 77, 21, 55}
# {33, 12, 44, 55}
# {2.4, 3, 5, 6, 'hello world'}
# {33, 12, 44, 55}
# [33, 12, 44, 55]
# {33, 66, 11, 44, 77, 22, 55}
# {33, 66, 11, 44, 77, 22, 55}
# {33, 66, 11, 44, 77, 22, 55}
# {44}
# {44}
# {44}
# {33, 11, 22}
# {33, 11, 22}
# {66, 77, 55}
# {66, 77, 55}

# %%
#6.Write a python program to convert decimal to binary,octal to hexadecimal with direct method. 

dec = 344
print("The decimal value of", dec, "is:")
print(bin(dec), "in binary.")
print(oct(dec), "in octal.")
print(hex(dec), "in hexadecimal.")
# Out:
# The decimal value of 344 is:
# 0b101011000 in binary.
# 0o530 in octal.
# 0x158 in hexadecimal.

# %%
#7.Implement arithmetic operators with examples.
#operators
#arithmetic operators
print("arithmetic operators")
a=25
b=5
print(a+b)
print(a-b)
print(a*b)
print(a**b)
print(a/b)
print(a//b)
print(a%b)
# Out:
# arithmetic operators
# 30
# 20
# 125
# 9765625
# 5.0
# 5
# 0

# %%
#8.Implement assignment operator with examples.
#assignment operator
a=25
b=5
c=a+b
print(c)
c-=a
print(c)
c+=a
print(c)
c-=b
print(c)
c+=b
print(c)
# Out:
# 30
# 5
# 30
# 25
# 30

# %%
#9.Implement comparision operator with examples.
#comparsion operateor
a=45
b=37
a>=b
print(a)
a==b
print(a)
a<=b
print(a)
a<<b
print(a)
a>>b
print(a)
a!=b
print(a)
# Out:
# 45
# 45
# 45
# 45
# 45
# 45

# %%
#10.Implement logical operators with examples.
#logical operators
a=False
b=True
print("a and b is",a and b)
print("a or b is",a or b)
print("a not b is", not b)
# Out:
# a and b is False
# a or b is True
# a not b is False

# %%
#11.Implement bitwise operators with examples.
#bitwise operators
a=9 #1001
b=12 #1100
print(a&b)#and
print(a|b)#or
print(-a)#not
print(a^b)#xor
print(a>>2)#right shift
print(a<<2)#left shift
# Out:
# 8
# 13
# -9
# 5
# 2
# 36

# %%
#12.Implement memebership operators with examples.
x="welcome"
print("w" in x)
y="python"
if("p" in y):
  print("present")
else:
  print("not present")
# Out:
# True
# present

# %%
#13.Implement identity operators with examples.
#identity operators
a=35
b=35
c="suraj"
d="suraj"
e=[12,23,34]
f=[12,23,34]
print(a is not b)
print(e is f)
print(c is d)
# Out:
# False
# False
# True

# %%
#14.Demonstrate negative indexeing for list and apply slicing.
list= [23,12,9,17,35,82,19,44,3]
print(list[::-1])
print(list[2:4])
print(list[2:7:5])
print(list[-3:-4:-2])
# Out:
# [3, 44, 19, 82, 35, 17, 9, 12, 23]
# [9, 17]
# [9]
# [19]

# %%
#15.Predict the output for the given code snippet and justify the result.
print('A series of character designated as one object known as a string'[::-1][4::3])
print('----------')
print('Welcome to python traing program'[3:10][::-1])
# Out:
# taawkcbe  tgerca  is
# ----------
# ot emoc

# %%
#16.Write a python program to get a desired output.
#input string is:
P_phrase="was it a car or a cat I saw"
print("the output string is:",P_phrase[::-1].upper())
# Out:
# the output string is: WAS I TAC A RO RAC A TI SAW

# %%
#17
x=int(input())
y=x*x
a='Z'*x
print(a)
b='O'*y
print(b)
print(a+b)
# Out:
# 5
# ZZZZZ
# OOOOOOOOOOOOOOOOOOOOOOOOO
# ZZZZZOOOOOOOOOOOOOOOOOOOOOOOOO
